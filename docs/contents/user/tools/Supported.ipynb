# %%
import molsysmt as msm

# %%
msm.supported.forms()

# %%
msm.supported.conversions()

# %%
msm.supported.viewers()
# Out:
# <style type="text/css">
# #T_02437_row0_col0, #T_02437_row1_col0, #T_02437_row2_col0, #T_02437_row3_col0, #T_02437_row4_col0, #T_02437_row5_col0, #T_02437_row6_col0, #T_02437_row10_col0, #T_02437_row11_col0, #T_02437_row16_col0, #T_02437_row17_col0, #T_02437_row18_col0, #T_02437_row19_col0, #T_02437_row20_col0, #T_02437_row22_col0, #T_02437_row23_col0, #T_02437_row24_col0, #T_02437_row26_col0, #T_02437_row27_col0, #T_02437_row28_col0, #T_02437_row29_col0, #T_02437_row32_col0, #T_02437_row33_col0, #T_02437_row36_col0, #T_02437_row37_col0, #T_02437_row39_col0, #T_02437_row40_col0, #T_02437_row41_col0, #T_02437_row42_col0, #T_02437_row43_col0, #T_02437_row44_col0, #T_02437_row45_col0, #T_02437_row46_col0, #T_02437_row47_col0, #T_02437_row50_col0, #T_02437_row51_col0, #T_02437_row52_col0, #T_02437_row56_col0, #T_02437_row59_col0, #T_02437_row60_col0, #T_02437_row63_col0 {
#   background-color: #E2856E;
#   text-align: center;
# }
# ...
